# %% [markdown]
# # Работа с файлами в Google Colab

# %%
# импортируем модуль os
import os

# из библиотеки google.colab импортируем класс files
from google.colab import files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # из библиотеки google.colab импортируем класс files
# ----> 2 from google.colab import files
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# выводим пути к папкам (dirpath) и наименования файлов (filenames) и после этого
for dirpath, _, filenames in os.walk("/content/"):

    # во вложенном цикле проходимся по названиям файлов
    for filename in filenames:

        # и соединяем путь до папок и входящие в эти папки файлы
        # с помощью метода path.join()
        print(os.path.join(dirpath, filename))

# %%
# посмотрим на содержимое папки content
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# заглянем внутрь sample_data
# !ls /content/sample_data/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# посмотрим на тип значений словаря uploaded
type(uploaded["test.csv"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # посмотрим на тип значений словаря uploaded
# ----> 2 type(uploaded['test.csv'])
#
# NameError: name 'uploaded' is not defined

# %%
# обратимся к ключу словаря uploaded и применим метод .decode()
uploaded_str = uploaded["test.csv"].decode()

# на выходе получаем обычную строку
print(type(uploaded_str))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # обратимся к ключу словаря uploaded и применим метод .decode()
# ----> 2 uploaded_str = uploaded['test.csv'].decode()
#       3
#       4 # на выходе получаем обычную строку
#       5 print(type(uploaded_str))
#
# NameError: name 'uploaded' is not defined

# %%
# выведем первые 35 значений
print(uploaded_str[:35])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # выведем первые 35 значений
# ----> 2 print(uploaded_str[:35])
#
# NameError: name 'uploaded_str' is not defined

# %%
# если разбить строку методом .split() по символам \r (возврат к началу строки) и \n (новая строка)
uploaded_list = uploaded_str.split("\r\n")

# на выходе мы получим список
type(uploaded_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # если разбить строку методом .split() по символам \r (возврат к началу строки) и \n (новая строка)
# ----> 2 uploaded_list = uploaded_str.split('\r\n')
#       3
#       4 # на выходе мы получим список
#       5 type(uploaded_list)
#
# NameError: name 'uploaded_str' is not defined

# %%
# пройдемся по этому списку, не забыв создать индекс с помощью функции enumerate()
for i, line in enumerate(uploaded_list):

    # начнем выводить записи
    print(line)

    # когда дойдем до четвертой строки
    if i == 3:

        # прервемся
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # пройдемся по этому списку, не забыв создать индекс с помощью функции enumerate()
# ----> 2 for i, line in enumerate(uploaded_list):
#       3
#       4   # начнем выводить записи
#       5   print(line)
#
# NameError: name 'uploaded_list' is not defined

# %%
# передадим функции open() адрес файла
# параметр 'r' означает, что мы хотим прочитать (read) файл
f1 = open("/content/train.csv")

# метод .read() помещает весь файл в одну строку
# выведем первые 142 символа (если параметр не указывать, выведется все содержимое)
print(f1.read(142))

# в конце файл необходимо закрыть
f1.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 # передадим функции open() адрес файла
#       2 # параметр 'r' означает, что мы хотим прочитать (read) файл
# ----> 3 f1 = open('/content/train.csv', 'r')
#       4
#       5 # метод .read() помещает весь файл в одну строку
#       6 # выведем первые 142 символа (если параметр не указывать, выведется все содержимое)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/train.csv'

# %%
# снова откроем файл
f2 = open("/content/train.csv")

# пройдемся по нашему объекту в цикле for и параллельно создадим индекс
for i, line in enumerate(f2):

    # выведем строки без служебных символов по краям
    print(line.strip())

    # дойдя до четвертой строки, прервемся
    if i == 3:
        break

# не забудем закрыть файл
f2.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # снова откроем файл
# ----> 2 f2 = open('/content/train.csv', 'r')
#       3
#       4 # пройдемся по нашему объекту в цикле for и параллельно создадим индекс
#       5 for i, line in enumerate(f2):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/train.csv'

# %%
# скажем Питону: "открой файл  и назови его f3"
with open("/content/test.csv") as f3:

    # "пройдись по строкам без служебных символов"
    for i, line in enumerate(f3):
        print(line.strip())

        # и "прервись на четвертой строке"
        if i == 3:
            break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # скажем Питону: "открой файл  и назови его f3"
# ----> 2 with open('/content/test.csv', 'r') as f3:
#       3
#       4   # "пройдись по строкам без служебных символов"
#       5   for i, line in enumerate(f3):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/test.csv'

# %%
# применим метод .download() объекта files
files.download("/content/result.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # применим метод .download() объекта files
# ----> 2 files.download('/content/result.csv')
#
# NameError: name 'files' is not defined
